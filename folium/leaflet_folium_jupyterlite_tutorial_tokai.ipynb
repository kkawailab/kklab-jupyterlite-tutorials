# %% [markdown]
# # JupyterLite で学ぶ Leaflet / folium 入門チュートリアル
#
# このノートブックは、**JupyterLite（ブラウザだけで動く Jupyter 環境）** 上で、
# JavaScript の地図ライブラリ **Leaflet** を Python から扱うためのラッパーライブラリ **folium** を使い、
# インタラクティブな地図を表示・操作する方法を学ぶためのチュートリアルです。
#
# 主な内容：
# - folium / Leaflet の概要
# - 基本の地図表示
# - マーカーとポップアップ
# - 複数地点の可視化（ループ・DataFrame）
# - タイルレイヤの変更
# - GeoJSON の表示
# - ミニ演習
#
# ※ JupyterLite 上で folium を利用するために、純 Python パッケージとして `micropip` からインストールしてみます。

# %% [markdown]
# ## 0. 環境準備（JupyterLite 用）
#
# このノートブックは **JupyterLite（Pyodide）** を想定しています。
#
# まず、folium をインストールし、必要なライブラリをインポートします。
# ※ ネットワーク制限や環境によってはインストールに失敗することがあります。

# %%
# folium は純 Python パッケージのため、micropip でインストールを試みます。
try:
    import folium
except ImportError:
    try:
        import micropip
        await micropip.install("folium")
        import folium
    except Exception as e:
        print("folium のインストールに失敗しました:", e)
        print("この環境で folium が利用できない場合があります。")

import pandas as pd
import numpy as np

print("ライブラリの読み込みが完了しました（エラーが出ていなければ OK）。")
# Out:
# ライブラリの読み込みが完了しました（エラーが出ていなければ OK）。

# %% [markdown]
# ## 1. folium と Leaflet の概要
#
# **Leaflet** は、ブラウザ上で動作する軽量な JavaScript 製の地図ライブラリです。
# OpenStreetMap などのタイル地図をベースに、マーカーやポリゴン・ポリラインなどを簡単に描画できます。
#
# **folium** は、この Leaflet を Python から扱うためのラッパーライブラリで、
# Jupyter Notebook / JupyterLite の中でインタラクティブな地図を表示できます。
#
# folium の基本的な使い方は：
# 1. `folium.Map` オブジェクトを作る
# 2. `folium.Marker` などで要素を追加
# 3. Notebook 上でオブジェクトを表示
# という流れです。

# %% [markdown]
# ## 2. 基本の地図表示
#
# まずは、もっとも基本的な「地図を 1 枚表示する」ことから始めます。
#
# ここでは例として、静岡県浜松市付近の緯度経度（35.17, 137.78 あたり）を中心に表示してみます。

# %% [markdown]
# ### 2.1 シンプルな地図

# %%
# 浜松市付近の座標（緯度・経度）
center = [34.7108, 137.7260]

m = folium.Map(location=center, zoom_start=12)

# Notebook 上で地図オブジェクトを評価すると、HTML として表示されます
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_081fd58d6d0e396e2603aa653805abb2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_081fd58d6d0e396e2603aa653805abb2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_081fd58d6d0e396e2603aa653805abb2 = L.map(
#                 &quot;map_081fd58d6d0e396e2603aa653805abb2&quot;,
#                 {
#                     center: [34.7108, 137.726],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4179e1a824927794c10bacc7617a8d9c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4179e1a824927794c10bacc7617a8d9c.addTo(map_081fd58d6d0e396e2603aa653805abb2);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 2章 練習問題
#
# 1. 自分の住んでいる地域、または行ってみたい都市の緯度・経度を調べて、その地点を中心とした地図を表示しなさい。
# 2. `zoom_start` の値を 5, 10, 15 などに変えて、ズームレベルの違いを体験しなさい。
# 3. 世界地図レベル（例：`location=[0, 0], zoom_start=2`）で表示した地図も試し、日本との位置関係を確認しなさい。

# %% [markdown]
# ## 3. マーカーとポップアップ
#
# 地図に「印（ピン）」を立てるには、`folium.Marker` を使います。
# クリックしたときに表示されるポップアップ文字列も簡単に設定できます。

# %% [markdown]
# ### 3.1 浜松駅にマーカーを立てる例

# %%
# 浜松駅付近
hamamatsu_station = [34.7036, 137.7340]

m = folium.Map(location=center, zoom_start=14)
folium.Marker(
    location=hamamatsu_station,
    popup="JR浜松駅",
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_80a150a543c89c1b29ff6a5097694f61 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_80a150a543c89c1b29ff6a5097694f61&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_80a150a543c89c1b29ff6a5097694f61 = L.map(
#                 &quot;map_80a150a543c89c1b29ff6a5097694f61&quot;,
#                 {
#                     center: [34.7108, 137.726],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e6cbc0b73d4257a362fa1426d54d8ec3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e6cbc0b73d4257a362fa1426d54d8ec3.addTo(map_80a150a543c89c1b29ff6a5097694f61);
#
#
#             var marker_35550f5db4524b52bafd503171f263f9 = L.marker(
#                 [34.7036, 137.734],
#                 {
# }
#             ).addTo(map_80a150a543c89c1b29ff6a5097694f61);
#
#
#         var popup_8aa43a55622a9d9d2db679c09bf2ad76 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a1aa5240036c08a3fdcc2ad94608aa8 = $(`&lt;div id=&quot;html_7a1aa5240036c08a3fdcc2ad94608aa8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JR浜松駅&lt;/div&gt;`)[0];
#                 popup_8aa43a55622a9d9d2db679c09bf2ad76.setContent(html_7a1aa5240036c08a3fdcc2ad94608aa8);
#
#
#
#         marker_35550f5db4524b52bafd503171f263f9.bindPopup(popup_8aa43a55622a9d9d2db679c09bf2ad76)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 3.2 複数のマーカーを追加する
#
# 複数の地点をリストで用意して、for ループでまとめてマーカーを追加してみます。

# %%
points = [
    {"name": "浜松駅", "lat": 34.7036, "lon": 137.7340},
    {"name": "浜松城公園", "lat": 34.7103, "lon": 137.7313},
    {"name": "中田島砂丘", "lat": 34.6729, "lon": 137.7439},
]

m = folium.Map(location=center, zoom_start=12)

for p in points:
    folium.Marker(
        location=[p["lat"], p["lon"]],
        popup=p["name"],
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_811fa0b66d9fbe869f42efa7ffe42c73 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_811fa0b66d9fbe869f42efa7ffe42c73&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_811fa0b66d9fbe869f42efa7ffe42c73 = L.map(
#                 &quot;map_811fa0b66d9fbe869f42efa7ffe42c73&quot;,
#                 {
#                     center: [34.7108, 137.726],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_532c310fa988e3be7e3e98768a6f9322 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_532c310fa988e3be7e3e98768a6f9322.addTo(map_811fa0b66d9fbe869f42efa7ffe42c73);
#
#
#             var marker_faf247d0a41763d556fc401c8551a598 = L.marker(
#                 [34.7036, 137.734],
#                 {
# }
#             ).addTo(map_811fa0b66d9fbe869f42efa7ffe42c73);
#
#
#         var popup_6b789051586aa59b0439465914647c2f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ff540b4703207838b28562006f91e893 = $(`&lt;div id=&quot;html_ff540b4703207838b28562006f91e893&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;浜松駅&lt;/div&gt;`)[0];
#                 popup_6b789051586aa59b0439465914647c2f.setContent(html_ff540b4703207838b28562006f91e893);
#
#
#
#         marker_faf247d0a41763d556fc401c8551a598.bindPopup(popup_6b789051586aa59b0439465914647c2f)
#         ;
#
#
#
#
#             var marker_2df6d3f76a53280e45f7cd82d6e8c1a7 = L.marker(
#                 [34.7103, 137.7313],
#                 {
# }
#             ).addTo(map_811fa0b66d9fbe869f42efa7ffe42c73);
#
#
#         var popup_7fa0030f4ad5ab5a55157216af85eebf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_61bd21197345031e8d0a1b4307afc644 = $(`&lt;div id=&quot;html_61bd21197345031e8d0a1b4307afc644&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;浜松城公園&lt;/div&gt;`)[0];
#                 popup_7fa0030f4ad5ab5a55157216af85eebf.setContent(html_61bd21197345031e8d0a1b4307afc644);
#
#
#
#         marker_2df6d3f76a53280e45f7cd82d6e8c1a7.bindPopup(popup_7fa0030f4ad5ab5a55157216af85eebf)
#         ;
#
#
#
#
#             var marker_c2844fd6f9d26d9acc22c6522c69e6fe = L.marker(
#                 [34.6729, 137.7439],
#                 {
# }
#             ).addTo(map_811fa0b66d9fbe869f42efa7ffe42c73);
#
#
#         var popup_1aca6371106a04eaeaff8aaed2d2c35f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50d5c0cd16e76327c3cb96b3a2d9d3c5 = $(`&lt;div id=&quot;html_50d5c0cd16e76327c3cb96b3a2d9d3c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;中田島砂丘&lt;/div&gt;`)[0];
#                 popup_1aca6371106a04eaeaff8aaed2d2c35f.setContent(html_50d5c0cd16e76327c3cb96b3a2d9d3c5);
#
#
#
#         marker_c2844fd6f9d26d9acc22c6522c69e6fe.bindPopup(popup_1aca6371106a04eaeaff8aaed2d2c35f)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 3章 練習問題
#
# 1. 自分の好きなスポット（3〜5か所）の名称と緯度経度を調べ、リストや DataFrame を使ってまとめてマーカーを表示しなさい。
# 2. `popup` に日本語の説明文をもう少し長めに入れてみて、どのように表示されるか確認しなさい。
# 3. `tooltip` 引数を使うと、マーカーにマウスを乗せたときに表示される短いテキストを指定できます。`tooltip` を試してみなさい。

# %% [markdown]
# ## 4. pandas DataFrame からマーカーを作る
#
# 地点情報が DataFrame として手元にある場合、行をループしながらマーカーを追加できます。
# ここでは、簡単な飲食店リストを DataFrame で作り、地図に可視化してみます。

# %% [markdown]
# ### 4.1 DataFrame を作成してマッピング

# %%
df_spots = pd.DataFrame({
    "name": ["カフェA", "レストランB", "ベーカリーC"],
    "lat": [34.706, 34.711, 34.699],
    "lon": [137.730, 137.720, 137.740],
    "category": ["cafe", "restaurant", "bakery"],
})

df_spots
# Out:
#      name     lat     lon    category
# 0    カフェA  34.706  137.73        cafe
# 1  レストランB  34.711  137.72  restaurant
# 2  ベーカリーC  34.699  137.74      bakery

# %%
m = folium.Map(location=center, zoom_start=13)

for _, row in df_spots.iterrows():
    folium.Marker(
        location=[row["lat"], row["lon"]],
        popup=f'{row["name"]} ({row["category"]})',
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_91c72907f7f5e8443549e83882f440d9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_91c72907f7f5e8443549e83882f440d9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_91c72907f7f5e8443549e83882f440d9 = L.map(
#                 &quot;map_91c72907f7f5e8443549e83882f440d9&quot;,
#                 {
#                     center: [34.7108, 137.726],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_64ac63b0912032ee65c088449d45982f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_64ac63b0912032ee65c088449d45982f.addTo(map_91c72907f7f5e8443549e83882f440d9);
#
#
#             var marker_4dd99eb2c1a53e035eeb05c71e89be02 = L.marker(
#                 [34.706, 137.73],
#                 {
# }
#             ).addTo(map_91c72907f7f5e8443549e83882f440d9);
#
#
#         var popup_12ac957c65628a9863a4ccd9746e2323 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64b1386bf20f3fd66830f5afdbfd04dc = $(`&lt;div id=&quot;html_64b1386bf20f3fd66830f5afdbfd04dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;カフェA (cafe)&lt;/div&gt;`)[0];
#                 popup_12ac957c65628a9863a4ccd9746e2323.setContent(html_64b1386bf20f3fd66830f5afdbfd04dc);
#
#
#
#         marker_4dd99eb2c1a53e035eeb05c71e89be02.bindPopup(popup_12ac957c65628a9863a4ccd9746e2323)
#         ;
#
#
#
#
#             var marker_3223609e5bd9f25b32062b6824015a9c = L.marker(
#                 [34.711, 137.72],
#                 {
# }
#             ).addTo(map_91c72907f7f5e8443549e83882f440d9);
#
#
#         var popup_29fa5993ae7ee943282f89b98eb76290 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae7b6daa6b60fa4457bd664b52540ef1 = $(`&lt;div id=&quot;html_ae7b6daa6b60fa4457bd664b52540ef1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;レストランB (restaurant)&lt;/div&gt;`)[0];
#                 popup_29fa5993ae7ee943282f89b98eb76290.setContent(html_ae7b6daa6b60fa4457bd664b52540ef1);
#
#
#
#         marker_3223609e5bd9f25b32062b6824015a9c.bindPopup(popup_29fa5993ae7ee943282f89b98eb76290)
#         ;
#
#
#
#
#             var marker_7020de741dfdc78af3a51694060b5479 = L.marker(
#                 [34.699, 137.74],
#                 {
# }
#             ).addTo(map_91c72907f7f5e8443549e83882f440d9);
#
#
#         var popup_741d1b7b62ccff11e64d5030fb4950b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b277387432a0b24dfa24068973a25fb9 = $(`&lt;div id=&quot;html_b277387432a0b24dfa24068973a25fb9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ベーカリーC (bakery)&lt;/div&gt;`)[0];
#                 popup_741d1b7b62ccff11e64d5030fb4950b6.setContent(html_b277387432a0b24dfa24068973a25fb9);
#
#
#
#         marker_7020de741dfdc78af3a51694060b5479.bindPopup(popup_741d1b7b62ccff11e64d5030fb4950b6)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 4章 練習問題
#
# 1. 独自の DataFrame（例：コンビニ、スーパー、病院など）を作成し、カテゴリ情報も含めてマーカーに表示しなさい。
# 2. カテゴリごとにマーカーの色を変えたい場合、どのようなロジックで `folium.Icon(color=...)` を指定すればよいか考えなさい。
# 3. 緯度・経度だけでなく、`url` 列を持たせ、ポップアップ内にリンク（HTML）を埋め込むこともできます。HTML 文字列を popup に与える方法を調べて試してみなさい。

# %% [markdown]
# ## 5. タイルレイヤ（地図のデザイン）を変える
#
# folium では、OpenStreetMap のほかにもさまざまなタイルレイヤを利用できます。
# `folium.Map` の `tiles` 引数で指定します。
#
# 例：
# - `"OpenStreetMap"`
# - `"CartoDB positron"`
# - `"CartoDB dark_matter"`
# - `"CartoDB positron"` など

# %% [markdown]
# ### 5.1 タイルを変えてみる例

# %%
tiles_list = ["OpenStreetMap", "CartoDB positron", "CartoDB dark_matter"]

maps = []
for t in tiles_list:
    m = folium.Map(location=center, zoom_start=12, tiles=t)
    maps.append(m)

# 最初のマップを表示（必要に応じて maps[1], maps[2] なども評価してみてください）
maps[0]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c88c1b8a61d3fdfdf2389545213efe31 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c88c1b8a61d3fdfdf2389545213efe31&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c88c1b8a61d3fdfdf2389545213efe31 = L.map(
#                 &quot;map_c88c1b8a61d3fdfdf2389545213efe31&quot;,
#                 {
#                     center: [34.7108, 137.726],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_78a1b72ff977640365c8344aa6a92c95 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_78a1b72ff977640365c8344aa6a92c95.addTo(map_c88c1b8a61d3fdfdf2389545213efe31);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 5章 練習問題
#
# 1. `tiles` に `"CartoDB positron"` を指定して地図を表示し、標準との見た目の違いを確認しなさい。
# 2. 教育・プレゼン用途で使うとき、どのようなタイルデザインが適切か、自分の使い方を想像して考えを述べなさい。
# 3. 背景地図の著作権表示（クレジット）は通常どう扱われているか、folium / Leaflet の表示を見て確認しなさい。

# %% [markdown]
# ## 6. GeoJSON レイヤの表示
#
# **GeoJSON** は、地理情報（ポイント・ライン・ポリゴンなど）を表現するための JSON 形式です。
# folium では、`folium.GeoJson` を使って GeoJSON データを地図に重ねて表示できます。
#
# ここでは、簡単なポリゴン（四角形）の GeoJSON をコード内に直接書いて表示してみます。

# %% [markdown]
# ### 6.1 シンプルなポリゴン GeoJSON の例

# %%
# 非常に簡略化された四角形ポリゴン（浜松駅付近のどこか）
simple_geojson = {
    "type": "FeatureCollection",
    "features": [
        {
            "type": "Feature",
            "properties": {"name": "サンプルエリア"},
            "geometry": {
                "type": "Polygon",
                "coordinates": [[
                    [137.728, 34.706],
                    [137.740, 34.706],
                    [137.740, 34.700],
                    [137.728, 34.700],
                    [137.728, 34.706]
                ]]
            }
        }
    ]
}

m = folium.Map(location=center, zoom_start=14)
folium.GeoJson(simple_geojson, name="geojson").add_to(m)
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ff3a2ec84471fa2f5abf81cc8fbaaed9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ff3a2ec84471fa2f5abf81cc8fbaaed9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ff3a2ec84471fa2f5abf81cc8fbaaed9 = L.map(
#                 &quot;map_ff3a2ec84471fa2f5abf81cc8fbaaed9&quot;,
#                 {
#                     center: [34.7108, 137.726],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0e31346365d70bd97d6e6818910b967d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0e31346365d70bd97d6e6818910b967d.addTo(map_ff3a2ec84471fa2f5abf81cc8fbaaed9);
#
#
#
#         function geo_json_9f5c14fa46050a5c73a25f202486fa36_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_9f5c14fa46050a5c73a25f202486fa36 = L.geoJson(null, {
#                 onEachFeature: geo_json_9f5c14fa46050a5c73a25f202486fa36_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_9f5c14fa46050a5c73a25f202486fa36_add (data) {
#             geo_json_9f5c14fa46050a5c73a25f202486fa36
#                 .addData(data);
#         }
#             geo_json_9f5c14fa46050a5c73a25f202486fa36_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[137.728, 34.706], [137.74, 34.706], [137.74, 34.7], [137.728, 34.7], [137.728, 34.706]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;\u30b5\u30f3\u30d7\u30eb\u30a8\u30ea\u30a2&quot;}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#         geo_json_9f5c14fa46050a5c73a25f202486fa36.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_9f5c14fa46050a5c73a25f202486fa36.addTo(map_ff3a2ec84471fa2f5abf81cc8fbaaed9);
#
#
#             var layer_control_38e911a6178c9a0a2d02a65faa79b792_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_0e31346365d70bd97d6e6818910b967d,
#                 },
#                 overlays :  {
#                     &quot;geojson&quot; : geo_json_9f5c14fa46050a5c73a25f202486fa36,
#                 },
#             };
#             let layer_control_38e911a6178c9a0a2d02a65faa79b792 = L.control.layers(
#                 layer_control_38e911a6178c9a0a2d02a65faa79b792_layers.base_layers,
#                 layer_control_38e911a6178c9a0a2d02a65faa79b792_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_ff3a2ec84471fa2f5abf81cc8fbaaed9);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 6章 練習問題
#
# 1. 自分で簡単なポリゴン（四角形や三角形）GeoJSON を作成し、色を変えて表示しなさい（`style_function` を使うと色指定ができます）。
# 2. 市区町村の境界 GeoJSON ファイルを入手した場合、JupyterLite にアップロードして `folium.GeoJson` で表示する手順を文章で説明しなさい。
# 3. ポリゴンにマウスを乗せたときに名前を表示するなど、インタラクティブな効果を付けたい場合、どのような拡張が考えられるか調べてみなさい。

# %% [markdown]
# ## 7. 総合ミニ演習：店舗マップ / 観光マップを作る
#
# 最後に、これまで学んだ内容を組み合わせて、
# 自分だけの「店舗マップ」や「観光マップ」を作ってみましょう。

# %% [markdown]
# ### 演習 1：自分の生活圏マップ
#
# 1. 自宅、よく行くスーパー、コンビニ、駅、カフェなど 5〜10 箇所の地点情報（名称・緯度・経度）を DataFrame やリストで作成しなさい。
# 2. folium を使って、これらの地点にマーカーを立てた地図を作成しなさい。
# 3. `popup` や `tooltip` に、その場所に対する自分のコメント（例：安い・静か・お気に入りなど）を加えなさい。
# 4. コードと地図のスクリーンショットをレポートなどに載せることを想定し、説明文をまとめてみなさい。

# %% [markdown]
# ### 演習 2：観光案内マップ
#
# 1. ある都市（例：浜松、名古屋、京都など）を 1 つ選び、主要な観光スポットや駅、ホテルなど 5〜10 箇所をピックアップしなさい。
# 2. 観光スポットごとにカテゴリ（寺社仏閣、博物館、グルメ、自然など）を設定し、カテゴリ別にマーカーの色やアイコンを変えることを検討しなさい。
# 3. 地図上でスポットを眺めながら、「どの順番で回ると効率が良さそうか」「どのエリアにスポットが集中しているか」などを考察し、文章にまとめなさい。

# %% [markdown]
# ---
#
# これで、JupyterLite 上での **Leaflet / folium 入門チュートリアル** は終了です。
#
# folium は、pandas や statsmodels と同様に、
# データ分析の結果を **地図上に可視化するための強力なツール** です。
#
# ぜひ、実際のデータ（例：調査地点、店舗売上、交通量、センサデータなど）にも応用してみてください。

# %% [markdown]
# ## 8. 発展編：東海4県（愛知・岐阜・三重・静岡）の GeoJSON を読み込む
#
# ここからは演習用の発展編として、**東海4県（愛知・岐阜・三重・静岡）** の境界データを
# GeoJSON 形式で読み込み、folium で表示することを想定したノートです。
#
# あらかじめ、東海4県の境界が入った GeoJSON ファイル（例：`tokai4_prefs.geojson`）を
# JupyterLite のファイルブラウザにアップロードしておきます。

# %% [markdown]
# ### 8.1 GeoJSON ファイルの前提
#
# この演習では、次のような前提で進めます：
#
# - ファイル名：`tokai4_prefs.geojson`
# - 内容：愛知・岐阜・三重・静岡の 4 県のポリゴン（またはマルチポリゴン）
# - 各フィーチャの属性に、少なくとも `name`（都道府県名） もしくは
#   `pref_name` のような名前の列が含まれていることを想定します。
#
# ※ 実際に利用する GeoJSON の属性名は、ファイルの中身を `!head` や
# `import json` で確認してから適宜読み替えてください。

# %% [markdown]
# ### 8.2 東海4県 GeoJSON の読み込みと表示
#
# `folium.GeoJson` を用いて、東海4県の境界を地図上に表示します。

# %%
import json
import folium

# 東海4県全体が見えるように、中心を名古屋付近に設定
center_tokai = [35.1709, 136.8815]  # 名古屋駅付近

# GeoJSON を読み込み
geojson_file = "tokai4_prefs.geojson"

with open(geojson_file, "r", encoding="utf-8") as f:
    tokai_geojson = json.load(f)

m_tokai = folium.Map(location=center_tokai, zoom_start=7)

folium.GeoJson(
    tokai_geojson,
    name="東海4県"
).add_to(m_tokai)

folium.LayerControl().add_to(m_tokai)

m_tokai
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_876c64779f5c8dec47aeb0ae31b0dc5a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_876c64779f5c8dec47aeb0ae31b0dc5a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_876c64779f5c8dec47aeb0ae31b0dc5a = L.map(
#                 &quot;map_876c64779f5c8dec47aeb0ae31b0dc5a&quot;,
#                 {
#                     center: [35.1709, 136.8815],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_41f4d3e2fd54625dd176cf5585465b8b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_41f4d3e2fd54625dd176cf5585465b8b.addTo(map_876c64779f5c8dec47aeb0ae31b0dc5a);
#
#
#
#         function geo_json_0895e9b7ed872a9ebd894da19b60474f_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_0895e9b7ed872a9ebd894da19b60474f = L.geoJson(null, {
#                 onEachFeature: geo_json_0895e9b7ed872a9ebd894da19b60474f_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_0895e9b7ed872a9ebd894da19b60474f_add (data) {
#             geo_json_0895e9b7ed872a9ebd894da19b60474f
#                 .addData(data);
#         }
#             geo_json_0895e9b7ed872a9ebd894da19b60474f_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[137.05819702148398, 36.37213134765631], [137.06390380859403, 36.37519836425779], [137.07080078124997, 36.379066467285185], [137.07870483398398, 36.38446807861328], [137.09109497070298, 36.383266448974645], [137.09460449218795, 36.38406753540037], [137.094299316406, 36.393398284912074], [137.09190368652298, 36.39686584472656], [137.09660339355497, 36.39899826049799], [137.10180664062497, 36.39946746826174], [137.106506347656, 36.4058647155762], [137.108703613281, 36.40833282470696], [137.111099243164, 36.41519927978518], [137.115997314453, 36.41673278808587], [137.118301391602, 36.41853332519533], [137.121002197266, 36.416934967040966], [137.121795654297, 36.41726684570312], [137.123199462891, 36.419868469238295], [137.129806518555, 36.42940139770509], [137.133499145508, 36.434932708740156], [137.138900756836, 36.438133239746065], [137.14329528808602, 36.43920135498046], [137.14279174804702, 36.444133758544886], [137.14599609375, 36.44599914550783], [137.154800415039, 36.44939804077147], [137.16070556640602, 36.456733703613345], [137.16529846191403, 36.45473480224607], [137.16949462890602, 36.45520019531247], [137.17539978027304, 36.45040130615229], [137.178100585938, 36.453399658203104], [137.18220520019503, 36.45259857177729], [137.19149780273403, 36.455333709716804], [137.19360351562503, 36.45226669311523], [137.19389343261696, 36.44726562500004], [137.19799804687503, 36.44526672363277], [137.20509338378903, 36.43433380126952], [137.20649719238304, 36.42793273925779], [137.20919799804696, 36.43166732788094], [137.21350097656304, 36.4306678771973], [137.21400451660202, 36.43906402587886], [137.21929931640597, 36.43939971923828], [137.22369384765597, 36.44419860839837], [137.23229980468804, 36.44519805908201], [137.23910522460898, 36.45180130004883], [137.24630737304696, 36.46139907836911], [137.24679565429696, 36.46179962158202], [137.24800109863295, 36.4620666503906], [137.25669860839798, 36.451663970947315], [137.26319885253898, 36.456535339355526], [137.266891479492, 36.46020126342774], [137.278900146484, 36.46513366699217], [137.28340148925798, 36.46306610107423], [137.287002563477, 36.461666107177685], [137.29919433593798, 36.458667755127045], [137.302505493164, 36.462131500244084], [137.308502197266, 36.46386718749996], [137.31539916992202, 36.46126556396478], [137.317001342773, 36.45959854125984], [137.316497802734, 36.45053100585944], [137.31329345703102, 36.44839859008792], [137.312896728516, 36.44326782226558], [137.312698364258, 36.44166564941413], [137.307891845703, 36.43866729736331], [137.30499267578102, 36.43560028076173], [137.307891845703, 36.431800842285185], [137.313491821289, 36.4250679016113], [137.320007324219, 36.42526626586912], [137.326293945313, 36.42853546142579], [137.331405639648, 36.430465698242216], [137.334594726563, 36.43086624145512], [137.33909606933602, 36.43366622924803], [137.34530639648403, 36.43373107910161], [137.348999023438, 36.433601379394545], [137.351501464844, 36.433864593505945], [137.35240173339804, 36.435001373291], [137.35870361328102, 36.43746566772458], [137.35820007324193, 36.445068359375036], [137.36259460449196, 36.45026779174804], [137.37179565429696, 36.45359802246092], [137.37779235839795, 36.452865600585866], [1

# %% [markdown]
# ### 8.3 スタイルを付けて見やすくする
#
# `style_function` を使うことで、ポリゴンの色や境界線の太さを変えることができます。
# ここでは、4県を同じ色で塗りつぶして表示してみます。

# %%
def style_function(feature):
    return {
        "fillColor": "#3186cc",
        "color": "black",
        "weight": 1,
        "fillOpacity": 0.4,
    }

m_tokai_style = folium.Map(location=center_tokai, zoom_start=7)

folium.GeoJson(
    tokai_geojson,
    name="東海4県",
    style_function=style_function
).add_to(m_tokai_style)

folium.LayerControl().add_to(m_tokai_style)

m_tokai_style
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_364c3224f07bc7173790ce5add6073d4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_364c3224f07bc7173790ce5add6073d4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_364c3224f07bc7173790ce5add6073d4 = L.map(
#                 &quot;map_364c3224f07bc7173790ce5add6073d4&quot;,
#                 {
#                     center: [35.1709, 136.8815],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1beb3adf1b30a29c8ca8cabd93acda66 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1beb3adf1b30a29c8ca8cabd93acda66.addTo(map_364c3224f07bc7173790ce5add6073d4);
#
#
#         function geo_json_aea1b13157291e0dc73d99fd423825b3_styler(feature) {
#             switch(feature.properties.nam) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.4, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_aea1b13157291e0dc73d99fd423825b3_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_aea1b13157291e0dc73d99fd423825b3 = L.geoJson(null, {
#                 onEachFeature: geo_json_aea1b13157291e0dc73d99fd423825b3_onEachFeature,
#
#                 style: geo_json_aea1b13157291e0dc73d99fd423825b3_styler,
#             ...{
# }
#         });
#
#         function geo_json_aea1b13157291e0dc73d99fd423825b3_add (data) {
#             geo_json_aea1b13157291e0dc73d99fd423825b3
#                 .addData(data);
#         }
#             geo_json_aea1b13157291e0dc73d99fd423825b3_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[137.05819702148398, 36.37213134765631], [137.06390380859403, 36.37519836425779], [137.07080078124997, 36.379066467285185], [137.07870483398398, 36.38446807861328], [137.09109497070298, 36.383266448974645], [137.09460449218795, 36.38406753540037], [137.094299316406, 36.393398284912074], [137.09190368652298, 36.39686584472656], [137.09660339355497, 36.39899826049799], [137.10180664062497, 36.39946746826174], [137.106506347656, 36.4058647155762], [137.108703613281, 36.40833282470696], [137.111099243164, 36.41519927978518], [137.115997314453, 36.41673278808587], [137.118301391602, 36.41853332519533], [137.121002197266, 36.416934967040966], [137.121795654297, 36.41726684570312], [137.123199462891, 36.419868469238295], [137.129806518555, 36.42940139770509], [137.133499145508, 36.434932708740156], [137.138900756836, 36.438133239746065], [137.14329528808602, 36.43920135498046], [137.14279174804702, 36.444133758544886], [137.14599609375, 36.44599914550783], [137.154800415039, 36.44939804077147], [137.16070556640602, 36.456733703613345], [137.16529846191403, 36.45473480224607], [137.16949462890602, 36.45520019531247], [137.17539978027304, 36.45040130615229], [137.178100585938, 36.453399658203104], [137.18220520019503, 36.45259857177729], [137.19149780273403, 36.455333709716804], [137.19360351562503, 36.45226669311523], [137.19389343261696, 36.44726562500004], [137.19799804687503, 36.44526672363277], [137.20509338378903, 36.43433380126952], [137.20649719238304, 36.42793273925779], [137.20919799804696, 36.43166732788094], [137.21350097656304, 36.4306678771973], [137.21400451660202, 36.43906402587886], [137.21929931640597, 36.43939971923828], [137.22369384765597, 36.44419860839837], [137.23229980468804, 36.44519805908201], [137.23910522460898, 36.45180130004883], [137.24630737304696, 36.46139907836911], [137.24679565429696, 36.46179962158202], [137.24800109863295, 36.4620666503906], [137.25669860839798, 36.451663970947315], [137.26319885253898, 36.456535339355526], [137.266891479492, 36.46020126342774], [137.278900146484, 36.46513366699217], [137.28340148925798, 36.46306610107423], [137.287002563477, 36.461666107177685], [137.29919433593798, 36.458667755127045], [137.302505493164, 36.462131500244084], [137.308502197266, 36.46386718749996], [137.31539916992202, 36.46126556396478], [137.317001342773, 36.45959854125984], [137.316497802734, 36.45053100585944], [137.31329345703102, 36.44839859008792], [137.312896728516, 36.44326782226558], [137.312698364258, 36.44166564941413], [137.307891845703, 36.43866729736331], [137.30499267578102, 36.43560028076173], [137.307891845703, 36.431800842285185], [137.313491821289, 36.4250679016113], [137.320007324219, 36.42526626586912], [137.326293945313, 36.42853546142579], [137.331405639648, 36.430465698242216], [137.334594726563, 36.43086624145512], [1

# %% [markdown]
# ### 8.4 県名ラベル付きマーカーの追加
#
# GeoJSON 内の属性から都道府県名を取り出し、その重心付近にマーカーを置くことで、
# 県名ラベル付きの地図を作ることができます。
#
# ここでは簡略版として、各ポリゴンの頂点の平均値を「だいたいの中心」としてマーカーを置きます
# （厳密な重心ではありませんが、演習には十分です）。

# %%
from shapely.geometry import shape

# shapely は Pyodide 環境では利用できないことがあるため、
# ここでは「座標の平均値」をとる簡易版も示します。
# まずは簡易版で実装し、shapely が使える環境では重心計算に置き換えてください。

def approximate_centroid(geometry):
    coords = []

    geom_type = geometry.get("type")
    if geom_type == "Polygon":
        for ring in geometry["coordinates"]:
            for lon, lat in ring:
                coords.append((lat, lon))
    elif geom_type == "MultiPolygon":
        for poly in geometry["coordinates"]:
            for ring in poly:
                for lon, lat in ring:
                    coords.append((lat, lon))
    else:
        return None

    if not coords:
        return None

    lats, lons = zip(*coords)
    return [sum(lats) / len(lats), sum(lons) / len(lons)]

m_tokai_labels = folium.Map(location=center_tokai, zoom_start=7)

for feature in tokai_geojson["features"]:
    geom = feature["geometry"]
    props = feature.get("properties", {})
    # 属性名は実際のファイルに合わせて変更してください
    name = props.get("name") or props.get("pref_name") or "不明"
    center_approx = approximate_centroid(geom)
    if center_approx is not None:
        folium.Marker(
            location=center_approx,
            popup=name,
            tooltip=name
        ).add_to(m_tokai_labels)

# 境界もあわせて表示
folium.GeoJson(
    tokai_geojson,
    name="東海4県",
    style_function=style_function
).add_to(m_tokai_labels)

folium.LayerControl().add_to(m_tokai_labels)

m_tokai_labels
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a5eb78c09c4cc0b433b2ef71f744fe0c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a5eb78c09c4cc0b433b2ef71f744fe0c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a5eb78c09c4cc0b433b2ef71f744fe0c = L.map(
#                 &quot;map_a5eb78c09c4cc0b433b2ef71f744fe0c&quot;,
#                 {
#                     center: [35.1709, 136.8815],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_51c59e7399333dcdd5924c9ecd06c5d0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_51c59e7399333dcdd5924c9ecd06c5d0.addTo(map_a5eb78c09c4cc0b433b2ef71f744fe0c);
#
#
#             var marker_41df36ebc9f1bc2be9c5bbda1d233544 = L.marker(
#                 [35.75999094645182, 137.04187611219618],
#                 {
# }
#             ).addTo(map_a5eb78c09c4cc0b433b2ef71f744fe0c);
#
#
#         var popup_df3a9198889c09b1afa8abd2a360ecb4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af567d82f039b0579f3c072cda0c20f8 = $(`&lt;div id=&quot;html_af567d82f039b0579f3c072cda0c20f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;岐阜県&lt;/div&gt;`)[0];
#                 popup_df3a9198889c09b1afa8abd2a360ecb4.setContent(html_af567d82f039b0579f3c072cda0c20f8);
#
#
#
#         marker_41df36ebc9f1bc2be9c5bbda1d233544.bindPopup(popup_df3a9198889c09b1afa8abd2a360ecb4)
#         ;
#
#
#
#
#             marker_41df36ebc9f1bc2be9c5bbda1d233544.bindTooltip(
#                 `&lt;div&gt;
#                      岐阜県
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_e9fe5e610b2de241a560ae9acaff6113 = L.marker(
#                 [35.002679434910256, 138.5138758998095],
#                 {
# }
#             ).addTo(map_a5eb78c09c4cc0b433b2ef71f744fe0c);
#
#
#         var popup_bf0efe6de198dfb92d36144bc3728ee5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ceb5972cba6c270a97bceeca5558bf05 = $(`&lt;div id=&quot;html_ceb5972cba6c270a97bceeca5558bf05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;静岡県&lt;/div&gt;`)[0];
#                 popup_bf0efe6de198dfb92d36144bc3728ee5.setContent(html_ceb5972cba6c270a97bceeca5558bf05);
#
#
#
#         marker_e9fe5e610b2de241a560ae9acaff6113.bindPopup(popup_bf0efe6de198dfb92d36144bc3728ee5)
#         ;
#
#
#
#
#             marker_e9fe5e610b2de241a560ae9acaff6113.bindTooltip(
#                 `&lt;div&gt;
#                      静岡県
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_f348d0363298f61a70d8c1f246e85f55 = L.marker(
#                 [34.93521453196474, 137.12889717905446],
#                 {
# }
#             ).addTo(map_a5eb78c09c4cc0b433b2ef71f744fe0c);
#
#
#         var popup_859aa470d3a0e3b476daec6488bcb260 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eef4b88f8627d117edeea44b7b3dee14 = $(`&lt;div id=&quot;html_eef4b88f8627d117edeea44b7b3dee14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;愛知県&lt;/div&gt;`)[0];
#                 popup_859aa470d3a0e3b476daec6488bcb260.setContent(html_eef4b88f8627d117edeea44b7b3dee14);
#
#
#
#         marker_f348d0363298f61a70d8c1f246e85f55.bindPopup(popup_859aa470d3a0e3b476daec6488bcb260)
#         ;
#
#
#
#
#             marker_f348d0363298f61a70d8c1f246e85f55.bindTooltip(
#                 `&lt;div&gt;
#                      愛知県
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_4a34f4471a553da030478d19cdc3c8f6 = L.marker(
#                 [34.38032647822342, 136.52562391511935],
#                 {
# }
#             ).addTo(map_a5eb78c09c4cc0b433b2ef71f744fe0c);
#
#
#         var popup_bee2bbbd3ea7253a3f71d0057c94a13f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0d9af68fedc04198337467686909c4b = $(`&lt;div id=&quot;html_f0d9af68fedc04198337467686909c4b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;三重県&lt;/div&gt;`)[0];
#                 popup_bee2bbbd3ea7253a3f71d0057c94a13f.setContent(html_f0d9af68fedc04198337467686909c4b);
#
#
#
#         marker_4a34f4471a553da030478d19cdc3c8f6.bindPopup(popup_bee2bbbd3ea7253a3f71d0057c94a13f)

# %% [markdown]
# ### 8章 練習問題
#
# 1. 東海4県の GeoJSON ファイル（`tokai4_prefs.geojson`）を実際に用意し、
#    8.2 のコードを使って地図上に表示しなさい。
# 2. 8.3 の `style_function` を改造して、県ごとに異なる色で塗り分けるようにしなさい。
#    （ヒント：属性 `name` の値に応じて色を変える関数を書く。）
# 3. 8.4 の「おおよその中心」計算を自分なりに改善してみなさい。
#    例：`Polygon` の最初のリングだけを使う／緯度・経度の範囲から中央を計算するなど。
# 4. もし shapely などの幾何ライブラリが使える環境であれば、本当の重心（centroid）を計算するコードに書き換えてみなさい。
